# %%
#Hola, este cuaderno sera utilizado para el proyecto final de curso

# %%
import pandas as pd
import numpy as np

# %%
print("¡Hola, Proyecto Final del Curso!")
# Out:
# ¡Hola, Proyecto Final del Curso!
